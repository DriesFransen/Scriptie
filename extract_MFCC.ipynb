# %%
import librosa
import librosa.display
import numpy as np

# %%
sound, sampling_rate = librosa.load("sound1.wav")

mfccs = librosa.feature.mfcc(y=sound, sr=sampling_rate, n_mfcc=12)

plt.figure(figsize=(10, 4))
librosa.display.specshow(mfccs, x_axis='time')
plt.colorbar()
plt.title('MFCC values of sound1.wav')
plt.tight_layout()
plt.show()
